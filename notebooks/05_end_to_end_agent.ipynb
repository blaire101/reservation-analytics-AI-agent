# %% [markdown]
# # 05 — End-to-End Agent

# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
print('Project root:', ROOT)
# Out:
# Project root: /Users/B1/ghome/github/online/reservation-analytics-ai-agent

# %% [markdown]
# ## Goal
#
# Run the whole local path after the individual pieces are clear.

# %%
from app.settings import load_settings
from app.data.backend import create_backend
from app.core.graph import ReservationAgent

settings = load_settings('config/local.env')
agent = ReservationAgent(settings, create_backend(settings))

# %%
questions = [
    'What does reserved but not ordered mean?',
    'How many users reserved Phone Mi 17 Pro in Germany for CMP001?',
    'What was the conversion rate for Phone Mi 17 Pro in Germany for CMP001?',
    'How many users reserved Phone Mi 17 Pro in Germany in August 2026?',
]

results = []
for question in questions:
    result = agent.invoke(question)
    results.append({
        'question': question,
        'route': result.get('route'),
        'status': result.get('status'),
        'answer': result.get('answer'),
    })

print(json.dumps(results, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "question": "What does reserved but not ordered mean?",
#     "route": "knowledge",
#     "status": "answered",
#     "answer": "Reserved but not ordered refers to a user who has expressed purchase intent by making a reservation during a campaign but did not subsequently place an order. This means the user has a reservation flag set to 1 but an order flag set to 0. In data terms, this condition is indicated by freserve_flag = 1 and forder_flag = 0, or equivalently by the tag ftag_reserved_not_paid = 1."
#   },
#   {
#     "question": "How many users reserved Phone Mi 17 Pro in Germany for CMP001?",
#     "route": "analytics",
#     "status": "answered",
#     "answer": "CMP001 — Mi 17 Launch (Germany): 8 reserved, 5 ordered, 3 not ordered, 62.50% conversion."
#   },
#   {
#     "question": "What was the conversion rate for Phone Mi 17 Pro in Germany for CMP001?",
#     "route": "analytics",
#     "status": "answered",
#     "answer": "CMP001 — Mi 17 Launch (Germany): 8 reserved, 5 ordered, 3 not ordered, 62.50% conversion."
#   },
#   {
#     "question": "How many users reserved Phone Mi 17 Pro in Germany in August 2026?",
#     "route": null,
#     "status": "clarification",
#     "answer": "Multiple campaigns matched. Choose one campaign_id: CMP001 — Mi 17 Launch; CMP002 — Back-to-School Campaign"
#   }
# ]

# %% [markdown]
# If you can explain each transition in the output, you understand the core repository. FastAPI, Docker, Athena, and SQL Gateway are then small serving or backend extensions.
