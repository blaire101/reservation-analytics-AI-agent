# %% [markdown]
# # 02 — LlamaIndex + FAISS RAG
#
# This notebook is intentionally small. Focus on one concept before moving to the next.

# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
print('Project root:', ROOT)
# Out:
# Project root: /mnt/data/raa_latest_work/reservation-analytics-ai-agent

# %% [markdown]
# ## Goal
#
# Understand the Knowledge path independently from LangGraph and SQL.
#
# Production code: `knowledge/kg_reservation_metrics.md + knowledge/kg_data_model.md` → `app/knowledge/rag.py`.

# %%
from app.settings import load_settings
from app.knowledge.rag import KnowledgeRAG

settings = load_settings('config/local.env')
rag = KnowledgeRAG(settings)
rag.answer('What does reserved but not ordered mean?')
# Out:
# 'A reserved-but-not-ordered user has freserve_flag=1 and forder_flag=0.'

# %% [markdown]
# ### Real RAG mode
#
# When `LLM_ENABLED=true`, `rag.py` builds:
#
# `LlamaIndex → OpenAI Embeddings → FAISS → Retriever → LLM`
#
# The default mode stays local so you can learn the project without external credentials.

# %%
print(settings.use_llm)
print(settings.knowledge_dir)
# Out:
# False
# /mnt/data/raa_latest_work/reservation-analytics-ai-agent/knowledge
